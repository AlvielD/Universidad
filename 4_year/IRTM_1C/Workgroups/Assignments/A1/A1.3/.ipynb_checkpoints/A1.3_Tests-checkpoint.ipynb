# %%
# Required packages:
from typing import Any, List, Tuple, Union
from numpy import ndarray

# For preprocessing text
import string
import re
from nltk.corpus import stopwords

# For training the model
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# For evaluating the model
from sklearn import metrics

# %%
def load_data(path: str) -> Tuple[List[str], List[str]]:
    """Loads data from file. Each except first (header) is a datapoint
    containing ID, Label, Email (content) separated by "\t".

    Args:
        path: Path to file from which to load data

    Returns:
        List of email contents and a list of labels coresponding to each email.
    """

    emails = []
    labels = []

    with open (path, "r", encoding="mbcs") as file:
        data = file.readlines()
        for line in data[1:]:
            line = line.split("\t")     # Split the line by withespaces
            emails.append(line[2])      # Append the content of the email

            # If the label is "spam" --> append 1, else append 0
            if line[1] == "spam":
                labels.append(1)
            else:
                labels.append(0)

    return emails, labels

# %%
def preprocess(doc: str) -> str:
    """Preprocesses text to prepare it for feature extraction.

    Args:
        doc: String comprising the unprocessed contents of some email file.

    Returns:
        String comprising the corresponding preprocessed text.
    """
    
    ## TOKENIZATION ##

    # Remove HTML markup using a regular expression.
    #html_regex = re.compile("<[^>]+>")
    #doc = html_regex.sub(" ", doc)

    
    # Replace puntuation using regular expresion
    # Replace punctuation marks with spaces.
    
    doc = re.sub("[^a-z0-9]", " ", doc)
    
    #for punct_mark in string.punctuation:
    #    doc = doc.replace(punct_mark, " ")
    
    # Split by whitespaces and turn to lowercase.
    doc = doc.lower().split()


    ## STOPWORD REMOVAL ##

    #str_doc = ""
    
    stop_words = stopwords.words("english")
    doc = [word for word in doc if word not in stop_words]
    
    #for word in doc:
    #    if word not in stop_words:
    #        str_doc = str_doc + " " + word

    ## SUFFIX-S STEMMING ## 

    #stemmed_doc = ""

    #for word in doc:
    #    stemmed_word = word[:-1] if word[-1] == "s" else word
    #    stemmed_doc = stemmed_doc + " " + stemmed_word

    #print(stemmed_doc)

    #return stemmed_doc
    return "".join(doc)

# %%
def preprocess_multiple(docs: List[str]) -> List[str]:
    """Preprocesses multiple texts to prepare them for feature extraction.

    Args:
        docs: List of strings, each consisting of the unprocessed contents
            of some email file.

    Returns:
        List of strings, each comprising the corresponding preprocessed
            text.
    """
    
    preprocessed_docs = []
    count = 0

    for doc in docs:
        preprocessed_docs.append(preprocess(doc))
        count += 1
        print("Doc preprocessed: ", count)

    return preprocessed_docs

# %%
def extract_features(
    train_dataset: List[str], test_dataset: List[str]
) -> Tuple[ndarray, ndarray]:
    """Extracts feature vectors from a preprocessed train and test datasets.

    Args:
        train_dataset: List of strings, each consisting of the preprocessed
            email content.
        test_dataset: List of strings, each consisting of the preprocessed
            email content.

    Returns:

    """
    ## EXTRACT VOCABULARY ##
    vocabulary = []

    for doc in train_dataset:
        doc_terms = doc.split() # Split document by whitespaces
        for term in doc_terms:
            if term not in vocabulary: 
                vocabulary.append(term)


    ## CREATION OF THE DOCUMENT-TERM MATRIX ##
    train_doc_term_matrix = ndarray(shape=(len(train_dataset), len(vocabulary)), dtype=int)

    for i in range(len(vocabulary)):
        for j in range(len(train_dataset)):
            train_doc_term_matrix[j][i] = doc.split().count(vocabulary[i])

    # We need to do the same for the document-term matrix of the test split
    test_doc_term_matrix = ndarray(shape=(len(test_dataset), len(vocabulary)), dtype=int)

    for i in range(len(vocabulary)):
        for j in range(len(test_dataset)):
            test_doc_term_matrix[j][i] = doc.split().count(vocabulary[i])

    return tuple((train_doc_term_matrix, test_doc_term_matrix))

# %%
def train(X: ndarray, y: List[int]) -> object:
    """Trains a classifier on extracted feature vectors.

    Args:
        X: Numerical array-like object (2D) representing the instances.
        y: Numerical array-like object (1D) representing the labels.

    Returns:
        A trained model object capable of predicting over unseen sets of
            instances.
    """

    # Model pipeline
    model = Pipeline([
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB()),
    ])

    # Train the model
    model.fit(X, y)

    return model

# %%
def evaluate(
    y: List[int], y_pred: List[int]
) -> Tuple[float, float, float, float]:
    """Evaluates a model's predictive performance with respect to a labeled
    dataset.

    Args:
        y: Numerical array-like object (1D) representing the true labels.
        y_pred: Numerical array-like object (1D) representing the predicted
            labels.

    Returns:
        A tuple of four values: recall, precision, F_1, and accuracy.
    """

    rec = metrics.recall_score(y, y_pred)
    prec = metrics.precision_score(y, y_pred)
    f1 = metrics.f1_score(y, y_pred)
    acc = metrics.accuracy_score(y, y_pred)

    return rec, prec, f1, acc

# %%
print("Loading data...")
train_data_raw, train_labels = load_data("data/train.tsv")
test_data_raw, test_labels = load_data("data/test.tsv")

print("Processing data...")
train_data = preprocess_multiple(train_data_raw)
test_data = preprocess_multiple(test_data_raw)

print("Extracting features...")
train_feature_vectors, test_feature_vectors = extract_features(train_data, test_data)

print("Training...")
classifier = train(train_feature_vectors, train_labels)

print("Applying model on test data...")
predicted_labels = classifier.predict(test_feature_vectors)

print("Evaluating")
recall, precision, f1, accuracy = evaluate(test_labels, predicted_labels)

print(f"Recall:\t{recall}")
print(f"Precision:\t{precision}")
print(f"F1:\t{f1}")
print(f"Accuracy:\t{accuracy}")
# Out:
# Loading data...
# Processing data...
# Doc preprocessed:  1
# Doc preprocessed:  2
# Doc preprocessed:  3
# Doc preprocessed:  4
# Doc preprocessed:  5
# Doc preprocessed:  6
# Doc preprocessed:  7
# Doc preprocessed:  8
# Doc preprocessed:  9
# Doc preprocessed:  10
# Doc preprocessed:  11
# Doc preprocessed:  12
# Doc preprocessed:  13
# Doc preprocessed:  14
# Doc preprocessed:  15
# Doc preprocessed:  16
# Doc preprocessed:  17
# Doc preprocessed:  18
# Doc preprocessed:  19
# Doc preprocessed:  20
# Doc preprocessed:  21
# Doc preprocessed:  22
# Doc preprocessed:  23
# Doc preprocessed:  24
# Doc preprocessed:  25
# Doc preprocessed:  26
# Doc preprocessed:  27
# Doc preprocessed:  28
# Doc preprocessed:  29
# Doc preprocessed:  30
# Doc preprocessed:  31
# Doc preprocessed:  32
# Doc preprocessed:  33
# Doc preprocessed:  34
# Doc preprocessed:  35
# Doc preprocessed:  36
# Doc preprocessed:  37
# Doc preprocessed:  38
# Doc preprocessed:  39
# Doc preprocessed:  40
# Doc preprocessed:  41
# Doc preprocessed:  42
# Doc preprocessed:  43
# Doc preprocessed:  44
# Doc preprocessed:  45
# Doc preprocessed:  46
# Doc preprocessed:  47
# Doc preprocessed:  48
# Doc preprocessed:  49
# Doc preprocessed:  50
# Doc preprocessed:  51
# Doc preprocessed:  52
# Doc preprocessed:  53
# Doc preprocessed:  54
# Doc preprocessed:  55
# Doc preprocessed:  56
# Doc preprocessed:  57
# Doc preprocessed:  58
# Doc preprocessed:  59
# Doc preprocessed:  60
# Doc preprocessed:  61
# Doc preprocessed:  62
# Doc preprocessed:  63
# Doc preprocessed:  64
# Doc preprocessed:  65
# Doc preprocessed:  66
# Doc preprocessed:  67
# Doc preprocessed:  68
# Doc preprocessed:  69
# Doc preprocessed:  70
# Doc preprocessed:  71
# Doc preprocessed:  72
# Doc preprocessed:  73
# Doc preprocessed:  74
# Doc preprocessed:  75
# Doc preprocessed:  76
# Doc preprocessed:  77
# Doc preprocessed:  78
# Doc preprocessed:  79
# Doc preprocessed:  80
# Doc preprocessed:  81
# Doc preprocessed:  82
# Doc preprocessed:  83
# Doc preprocessed:  84
# Doc preprocessed:  85
# Doc preprocessed:  86
# Doc preprocessed:  87
# Doc preprocessed:  88
# Doc preprocessed:  89
# Doc preprocessed:  90
# Doc preprocessed:  91
# Doc preprocessed:  92
# Doc preprocessed:  93
# Doc preprocessed:  94
# Doc preprocessed:  95
# Doc preprocessed:  96
# Doc preprocessed:  97
# Doc preprocessed:  98
# Doc preprocessed:  99
# Doc preprocessed:  100
# Doc preprocessed:  101
# Doc preprocessed:  102
# Doc preprocessed:  103
# Doc preprocessed:  104
# Doc preprocessed:  105
# Doc preprocessed:  106
# Doc preprocessed:  107
# Doc preprocessed:  108
# Doc preprocessed:  109
# Doc preprocessed:  110
# Doc preprocessed:  111
# Doc preprocessed:  112
# Doc preprocessed:  113
# Doc preprocessed:  114
# Doc preprocessed:  115
# Doc preprocessed:  116
# Doc preprocessed:  117
# Doc preprocessed:  118
# Doc preprocessed:  119
# Doc preprocessed:  120
# Doc preprocessed:  121
# Doc preprocessed:  122
# Doc preprocessed:  123
# Doc preprocessed:  124
# Doc preprocessed:  125
# Doc preprocessed:  126
# Doc preprocessed:  127
# Doc preprocessed:  128
# Doc preprocessed:  129
# Doc preprocessed:  130
# Doc preprocessed:  131
# Doc preprocessed:  132
# Doc preprocessed:  133
# Doc preprocessed:  134
# Doc preprocessed:  135
# Doc preprocessed:  136
# Doc preprocessed:  137
# Doc preprocessed:  138
# Doc preprocessed:  139
# Doc preprocessed:  140
# Doc preprocessed:  141
# Doc preprocessed:  142
# Doc preprocessed:  143
# Doc preprocessed:  144
# Doc preprocessed:  145
# Doc preprocessed:  146
# Doc preprocessed:  147
# Doc preprocessed:  148
# Doc preprocessed:  149
# Doc preprocessed:  150
# Doc preprocessed:  151
# Doc preprocessed:  152
# Doc preprocessed:  153
# Doc preprocessed:  154
# Doc preprocessed:  155
# Doc preprocessed:  156
# Doc preprocessed:  157
# Doc preprocessed:  158
# Doc preprocessed:  159
# Doc preprocessed:  160
# Doc preprocessed:  161
# Doc preprocessed:  162
# Doc preprocessed:  163
# Doc preprocessed:  164
# Doc preprocessed:  165
# Doc preprocessed:  166
# Doc preprocessed:  167
# Doc preprocessed:  168
# Doc preprocessed:  169
# Doc preprocessed:  170
# Doc preprocessed:  171
# Doc preprocessed:  172
# Doc preprocessed:  173
# Doc preprocessed:  174
# Doc preprocessed:  175
# Doc preprocessed:  176
# Doc preprocessed:  177
# Doc preprocessed:  178
# Doc preprocessed:  179
# Doc preprocessed:  180
# Doc preprocessed:  181
# Doc preprocessed:  182
# Doc preprocessed:  183
# Doc preprocessed:  184
# Doc preprocessed:  185
# Doc preprocessed:  186
# Doc preprocessed:  187
# Doc preprocessed:  188
# Doc preprocessed:  189
# Doc preprocessed:  190
# Doc preprocessed:  191
# Doc preprocessed:  192
# Doc preprocessed:  193
# Doc preprocessed:  194
# Doc preprocessed:  195
# Doc preprocessed:  196
# Doc preprocessed:  197
# Doc preprocessed:  198
# Doc preprocessed:  199
# Doc preprocessed:  200
# Doc preprocessed:  201
# Doc preprocessed:  202
# Doc preprocessed:  203
# Doc preprocessed:  204
# Doc preprocessed:  205
# Doc preprocessed:  206
# Doc preprocessed:  207
# Doc preprocessed:  208
# Doc preprocessed:  209
# Doc preprocessed:  210
# Doc preprocessed:  211
# Doc preprocessed:  212
# Doc preprocessed:  213
# Doc preprocessed:  214
# Doc preprocessed:  215
# Doc preprocessed:  216
# Doc preprocessed:  217
# Doc preprocessed:  218
# Doc preprocessed:  219
# Doc preprocessed:  220
# Doc preprocessed:  221
# Doc preprocessed:  222
# Doc preprocessed:  223
# Doc preprocessed:  224
# Doc preprocessed:  225
# Doc preprocessed:  226
# Doc preprocessed:  227
# Doc preprocessed:  228
# Doc preprocessed:  229
# Doc preprocessed:  230
# Doc preprocessed:  231
# Doc preprocessed:  232
# Doc preprocessed:  233
# Doc preprocessed:  234
# Doc preprocessed:  235
# Doc preprocessed:  236
# Doc preprocessed:  237
# Doc preprocessed:  238
# Doc preprocessed:  239
# Doc preprocessed:  240
# Doc preprocessed:  241
# Doc preprocessed:  242
# Doc preprocessed:  243
# Doc preprocessed:  244
# Doc preprocessed:  245
# Doc preprocessed:  246
# Doc preprocessed:  247
# Doc preprocessed:  248
# Doc preprocessed:  249
# Doc preprocessed:  250
# Doc preprocessed:  251
# Doc preprocessed:  252
# Doc preprocessed:  253
# Doc preprocessed:  254
# Doc preprocessed:  255
# Doc preprocessed:  256
# Doc preprocessed:  257
# Doc preprocessed:  258
# Doc preprocessed:  259
# Doc preprocessed:  260
# Doc preprocessed:  261
# Doc preprocessed:  262
# Doc preprocessed:  263
# Doc preprocessed:  264
# Doc preprocessed:  265
# Doc preprocessed:  266
# Doc preprocessed:  267
# Doc preprocessed:  268
# Doc preprocessed:  269
# Doc preprocessed:  270
# Doc preprocessed:  271
# Doc preprocessed:  272
# Doc preprocessed:  273
# Doc preprocessed:  274
# Doc preprocessed:  275
# Doc preprocessed:  276
# Doc preprocessed:  277
# Doc preprocessed:  278
# Doc preprocessed:  279
# Doc preprocessed:  280
# Doc preprocessed:  281
# Doc preprocessed:  282
# Doc preprocessed:  283
# Doc preprocessed:  284
# Doc preprocessed:  285
# Doc preprocessed:  286
# Doc preprocessed:  287
# Doc preprocessed:  288
# Doc preprocessed:  289
# Doc preprocessed:  290
# Doc preprocessed:  291
# Doc preprocessed:  292
# Doc preprocessed:  293
# Doc preprocessed:  294
# Doc preprocessed:  295
# Doc preprocessed:  296
# Doc preprocessed:  297
# Doc preprocessed:  298
# Doc preprocessed:  299
# Doc preprocessed:  300
# Doc preprocessed:  301
# Doc preprocessed:  302
# Doc preprocessed:  303
# Doc preprocessed:  304
# Doc preprocessed:  305
# Doc preprocessed:  306
# Doc preprocessed:  307
# Doc preprocessed:  308
# Doc preprocessed:  309
# Doc preprocessed:  310
# Doc preprocessed:  311
# Doc preprocessed:  312
# Doc preprocessed:  313
# Doc preprocessed:  314
# Doc preprocessed:  315
# Doc preprocessed:  316
# Doc preprocessed:  317
# Doc preprocessed:  318
# Doc preprocessed:  319
# Doc preprocessed:  320
# Doc preprocessed:  321
# Doc preprocessed:  322
# Doc preprocessed:  323
# Doc preprocessed:  324
# Doc preprocessed:  325
# Doc preprocessed:  326
# Doc preprocessed:  327
# Doc preprocessed:  328
# Doc preprocessed:  329
# Doc preprocessed:  330
# Doc preprocessed:  331
# Doc preprocessed:  332
# Doc preprocessed:  333
# Doc preprocessed:  334
# Doc preprocessed:  335
# Doc preprocessed:  336
# Doc preprocessed:  337
# Doc preprocessed:  338
# Doc preprocessed:  339
# Doc preprocessed:  340
# Doc preprocessed:  341
# Doc preprocessed:  342
# Doc preprocessed:  343
# Doc preprocessed:  344
# Doc preprocessed:  345
# Doc preprocessed:  346
# Doc preprocessed:  347
# Doc preprocessed:  348
# Doc preprocessed:  349
# Doc preprocessed:  350
# Doc preprocessed:  351
# Doc preprocessed:  352
# Doc preprocessed:  353
# Doc preprocessed:  354
# Doc preprocessed:  355
# Doc preprocessed:  356
# Doc preprocessed:  357
# Doc preprocessed:  358
# Doc preprocessed:  359
# Doc preprocessed:  360
# Doc preprocessed:  361
# Doc preprocessed:  362
# Doc preprocessed:  363
# Doc preprocessed:  364
# Doc preprocessed:  365
# Doc preprocessed:  366
# Doc preprocessed:  367
# Doc preprocessed:  368
# Doc preprocessed:  369
# Doc preprocessed:  370
# Doc preprocessed:  371
# Doc preprocessed:  372
# Doc preprocessed:  373
# Doc preprocessed:  374
# Doc preprocessed:  375
# Doc preprocessed:  376
# Doc preprocessed:  377
# Doc preprocessed:  378
# Doc preprocessed:  379
# Doc preprocessed:  380
# Doc preprocessed:  381
# Doc preprocessed:  382
# Doc preprocessed:  383
# Doc preprocessed:  384
# Doc preprocessed:  385
# Doc preprocessed:  386
# Doc preprocessed:  387
# Doc preprocessed:  388
# Doc preprocessed:  389
# Doc preprocessed:  390
# Doc preprocessed:  391
# Doc preprocessed:  392
# Doc preprocessed:  393
# Doc preprocessed:  394
# Doc preprocessed:  395
# Doc preprocessed:  396
# Doc preprocessed:  397
# Doc preprocessed:  398
# Doc preprocessed:  399
# Doc preprocessed:  400
# Doc preprocessed:  401
# Doc preprocessed:  402
# Doc preprocessed:  403
# Doc preprocessed:  404
# Doc preprocessed:  405
# Doc preprocessed:  406
# Doc preprocessed:  407
# Doc preprocessed:  408
# Doc preprocessed:  409
# Doc preprocessed:  410
# Doc preprocessed:  411
# Doc preprocessed:  412
# Doc preprocessed:  413
# Doc preprocessed:  414
# Doc preprocessed:  415
# Doc preprocessed:  416
# Doc preprocessed:  417
# Doc preprocessed:  418
# Doc preprocessed:  419
# Doc preprocessed:  420
# Doc preprocessed:  421
# Doc preprocessed:  422
# Doc preprocessed:  423
# Doc preprocessed:  424
# Doc preprocessed:  425
# Doc preprocessed:  426
# Doc preprocessed:  427
# Doc preprocessed:  428
# Doc preprocessed:  429
# Doc preprocessed:  430
# Doc preprocessed:  431
# Doc preprocessed:  432
# Doc preprocessed:  433
# Doc preprocessed:  434
# Doc preprocessed:  435
# Doc preprocessed:  436
# Doc preprocessed:  437
# Doc preprocessed:  438
# Doc preprocessed:  439
# Doc preprocessed:  440
# Doc preprocessed:  441
# Doc preprocessed:  442
# Doc preprocessed:  443
# Doc preprocessed:  444
# Doc preprocessed:  445
# Doc preprocessed:  446
# Doc preprocessed:  447
# Doc preprocessed:  448
# Doc preprocessed:  449
# Doc preprocessed:  450
# Doc preprocessed:  451
# Doc preprocessed:  452
# Doc preprocessed:  453
# Doc preprocessed:  454
# Doc preprocessed:  455
# Doc preprocessed:  456
# Doc preprocessed:  457
# Doc preprocessed:  458
# Doc preprocessed:  459
# Doc preprocessed:  460
# Doc preprocessed:  461
# Doc preprocessed:  462
# Doc preprocessed:  463
# Doc preprocessed:  464
# Doc preprocessed:  465
# Doc preprocessed:  466
# Doc preprocessed:  467
# Doc preprocessed:  468
# Doc preprocessed:  469
# Doc preprocessed:  470
# Doc preprocessed:  471
# Doc preprocessed:  472
# Doc preprocessed:  473
# Doc preprocessed:  474
# Doc preprocessed:  475
# Doc preprocessed:  476
# Doc preprocessed:  477
# Doc preprocessed:  478
# Doc preprocessed:  479
# Doc preprocessed:  480
# Doc preprocessed:  481
# Doc preprocessed:  482
# Doc preprocessed:  483
# Doc preprocessed:  484
# Doc preprocessed:  485
# Doc preprocessed:  486
# Doc preprocessed:  487
# Doc preprocessed:  488
# Doc preprocessed:  489
# Doc preprocessed:  490
# Doc preprocessed:  491
# Doc preprocessed:  492
# Doc preprocessed:  493
# Doc preprocessed:  494
# Doc preprocessed:  495
# Doc preprocessed:  496
# Doc preprocessed:  497
# Doc preprocessed:  498
# Doc preprocessed:  499
# Doc preprocessed:  500
# Doc preprocessed:  501
# Doc preprocessed:  502
# Doc preprocessed:  503
# Doc preprocessed:  504
# Doc preprocessed:  505
# Doc preprocessed:  506
# Doc preprocessed:  507
# Doc preprocessed:  508
# Doc preprocessed:  509
# Doc preprocessed:  510
# Doc preprocessed:  511
# Doc preprocessed:  512
# Doc preprocessed:  513
# Doc preprocessed:  514
# Doc preprocessed:  515
# Doc preprocessed:  516
# Doc preprocessed:  517
# Doc preprocessed:  518
# Doc preprocessed:  519
# Doc preprocessed:  520
# Doc preprocessed:  521
# Doc preprocessed:  522
# Doc preprocessed:  523
# Doc preprocessed:  524
# Doc preprocessed:  525
# Doc preprocessed:  526
# Doc preprocessed:  527
# Doc preprocessed:  528
# Doc preprocessed:  529
# Doc preprocessed:  530
# Doc preprocessed:  531
# Doc preprocessed:  532
# Doc preprocessed:  533
# Doc preprocessed:  534
# Doc preprocessed:  535
# Doc preprocessed:  536
# Doc preprocessed:  537
# Doc preprocessed:  538
# Doc preprocessed:  539
# Doc preprocessed:  540
# Doc preprocessed:  541
# Doc preprocessed:  542
# Doc preprocessed:  543
# Doc preprocessed:  544
# Doc preprocessed:  545
# Doc preprocessed:  546
# Doc preprocessed:  547
# Doc preprocessed:  548
# Doc preprocessed:  549
# Doc preprocessed:  550
# Doc preprocessed:  551
# Doc preprocessed:  552
# Doc preprocessed:  553
# Doc preprocessed:  554
# Doc preprocessed:  555
# Doc preprocessed:  556
# Doc preprocessed:  557
# Doc preprocessed:  558
# Doc preprocessed:  559
# Doc preprocessed:  560
# Doc preprocessed:  561
# Doc preprocessed:  562
# Doc preprocessed:  563
# Doc preprocessed:  564
# Doc preprocessed:  565
# Doc preprocessed:  566
# Doc preprocessed:  567
# Doc preprocessed:  568
# Doc preprocessed:  569
# Doc preprocessed:  570
# Doc preprocessed:  571
# Doc preprocessed:  572
# Doc preprocessed:  573
# Doc preprocessed:  574
# Doc preprocessed:  575
# Doc preprocessed:  576
# Doc preprocessed:  577
# Doc preprocessed:  578
# Doc preprocessed:  579
# Doc preprocessed:  580
# Doc preprocessed:  581
# Doc preprocessed:  582
# Doc preprocessed:  583
# Doc preprocessed:  584
# Doc preprocessed:  585
# Doc preprocessed:  586
# Doc preprocessed:  587
# Doc preprocessed:  588
# Doc preprocessed:  589
# Doc preprocessed:  590
# Doc preprocessed:  591
# Doc preprocessed:  592
# Doc preprocessed:  593
# Doc preprocessed:  594
# Doc preprocessed:  595
# Doc preprocessed:  596
# Doc preprocessed:  597
# Doc preprocessed:  598
# Doc preprocessed:  599
# Doc preprocessed:  600
# Doc preprocessed:  601
# Doc preprocessed:  602
# Doc preprocessed:  603
# Doc preprocessed:  604
# Doc preprocessed:  605
# Doc preprocessed:  606
# Doc preprocessed:  607
# Doc preprocessed:  608
# Doc preprocessed:  609
# Doc preprocessed:  610
# Doc preprocessed:  611
# Doc preprocessed:  612
# Doc preprocessed:  613
# Doc preprocessed:  614
# Doc preprocessed:  615
# Doc preprocessed:  616
# Doc preprocessed:  617
# Doc preprocessed:  618
# Doc preprocessed:  619
# Doc preprocessed:  620
# Doc preprocessed:  621
# Doc preprocessed:  622
# Doc preprocessed:  623
# Doc preprocessed:  624
# Doc preprocessed:  625
# Doc preprocessed:  626
# Doc preprocessed:  627
# Doc preprocessed:  628
# Doc preprocessed:  629
# Doc preprocessed:  630
# Doc preprocessed:  631
# Doc preprocessed:  632
# Doc preprocessed:  633
# Doc preprocessed:  634
# Doc preprocessed:  635
# Doc preprocessed:  636
# Doc preprocessed:  637
# Doc preprocessed:  638
# Doc preprocessed:  639
# Doc preprocessed:  640
# Doc preprocessed:  641
# Doc preprocessed:  642
# Doc preprocessed:  643
# Doc preprocessed:  644
# Doc preprocessed:  645
# Doc preprocessed:  646
# Doc preprocessed:  647
# Doc preprocessed:  648
# Doc preprocessed:  649
# Doc preprocessed:  650
# Doc preprocessed:  651
# Doc preprocessed:  652
# Doc preprocessed:  653
# Doc preprocessed:  654
# Doc preprocessed:  655
# Doc preprocessed:  656
# Doc preprocessed:  657
# Doc preprocessed:  658
# Doc preprocessed:  659
# Doc preprocessed:  660
# Doc preprocessed:  661
# Doc preprocessed:  662
# Doc preprocessed:  663
# Doc preprocessed:  664
# Doc preprocessed:  665
# Doc preprocessed:  666
# Doc preprocessed:  667
# Doc preprocessed:  668
# Doc preprocessed:  669
# Doc preprocessed:  670
# Doc preprocessed:  671
# Doc preprocessed:  672
# Doc preprocessed:  673
# Doc preprocessed:  674
# Doc preprocessed:  675
# Doc preprocessed:  676
# Doc preprocessed:  677
# Doc preprocessed:  678
# Doc preprocessed:  679
# Doc preprocessed:  680
# Doc preprocessed:  681
# Doc preprocessed:  682
# Doc preprocessed:  683
# Doc preprocessed:  684
# Doc preprocessed:  685
# Doc preprocessed:  686
# Doc preprocessed:  687
# Doc preprocessed:  688
# Doc preprocessed:  689
# Doc preprocessed:  690
# Doc preprocessed:  691
# Doc preprocessed:  692
# Doc preprocessed:  693
# Doc preprocessed:  694
# Doc preprocessed:  695
# Doc preprocessed:  696
# Doc preprocessed:  697
# Doc preprocessed:  698
# Doc preprocessed:  699
# Doc preprocessed:  700
# Doc preprocessed:  701
# Doc preprocessed:  702
# Doc preprocessed:  703
# Doc preprocessed:  704
# Doc preprocessed:  705
# Doc preprocessed:  706
# Doc preprocessed:  707
# Doc preprocessed:  708
# Doc preprocessed:  709
# Doc preprocessed:  710
# Doc preprocessed:  711
# Doc preprocessed:  712
# Doc preprocessed:  713
# Doc preprocessed:  714
# Doc preprocessed:  715
# Doc preprocessed:  716
# Doc preprocessed:  717
# Doc preprocessed:  718
# Doc preprocessed:  719
# Doc preprocessed:  720
# Doc preprocessed:  721
# Doc preprocessed:  722
# Doc preprocessed:  723
# Doc preprocessed:  724
# Doc preprocessed:  725
# Doc preprocessed:  726
# Doc preprocessed:  727
# Doc preprocessed:  728
# Doc preprocessed:  729
# Doc preprocessed:  730
# Doc preprocessed:  731
# Doc preprocessed:  732
# Doc preprocessed:  733
# Doc preprocessed:  734
# Doc preprocessed:  735
# Doc preprocessed:  736
# Doc preprocessed:  737
# Doc preprocessed:  738
# Doc preprocessed:  739
# Doc preprocessed:  740
# Doc preprocessed:  741
# Doc preprocessed:  742
# Doc preprocessed:  743
# Doc preprocessed:  744
# Doc preprocessed:  745
# Doc preprocessed:  746
# Doc preprocessed:  747
# Doc preprocessed:  748
# Doc preprocessed:  749
# Doc preprocessed:  750
# Doc preprocessed:  751
# Doc preprocessed:  752
# Doc preprocessed:  753
# Doc preprocessed:  754
# Doc preprocessed:  755
# Doc preprocessed:  756
# Doc preprocessed:  757
# Doc preprocessed:  758
# Doc preprocessed:  759
# Doc preprocessed:  760
# Doc preprocessed:  761
# Doc preprocessed:  762
# Doc preprocessed:  763
# Doc preprocessed:  764
# Doc preprocessed:  765
# Doc preprocessed:  766
# Doc preprocessed:  767
# Doc preprocessed:  768
# Doc preprocessed:  769
# Doc preprocessed:  770
# Doc preprocessed:  771
# Doc preprocessed:  772
# Doc preprocessed:  773
# Doc preprocessed:  774
# Doc preprocessed:  775
# Doc preprocessed:  776
# Doc preprocessed:  777
# Doc preprocessed:  778
# Doc preprocessed:  779
# Doc preprocessed:  780
# Doc preprocessed:  781
# Doc preprocessed:  782
# Doc preprocessed:  783
# Doc preprocessed:  784
# Doc preprocessed:  785
# Doc preprocessed:  786
# Doc preprocessed:  787
# Doc preprocessed:  788
# Doc preprocessed:  789
# Doc preprocessed:  790
# Doc preprocessed:  791
# Doc preprocessed:  792
# Doc preprocessed:  793
# Doc preprocessed:  794
# Doc preprocessed:  795
# Doc preprocessed:  796
# Doc preprocessed:  797
# Doc preprocessed:  798
# Doc preprocessed:  799
# Doc preprocessed:  800
# Doc preprocessed:  801
# Doc preprocessed:  802
# Doc preprocessed:  803
# Doc preprocessed:  804
# Doc preprocessed:  805
# Doc preprocessed:  806
# Doc preprocessed:  807
# Doc preprocessed:  808
# Doc preprocessed:  809
# Doc preprocessed:  810
# Doc preprocessed:  811
# Doc preprocessed:  812
# Doc preprocessed:  813
# Doc preprocessed:  814
# Doc preprocessed:  815
# Doc preprocessed:  816
# Doc preprocessed:  817
# Doc preprocessed:  818
# Doc preprocessed:  819
# Doc preprocessed:  820
# Doc preprocessed:  821
# Doc preprocessed:  822
# Doc preprocessed:  823
# Doc preprocessed:  824
# Doc preprocessed:  825
# Doc preprocessed:  826
# Doc preprocessed:  827
# Doc preprocessed:  828
# Doc preprocessed:  829
# Doc preprocessed:  830
# Doc preprocessed:  831
# Doc preprocessed:  832
# Doc preprocessed:  833
# Doc preprocessed:  834
# Doc preprocessed:  835
# Doc preprocessed:  836
# Doc preprocessed:  837
# Doc preprocessed:  838
# Doc preprocessed:  839
# Doc preprocessed:  840
# Doc preprocessed:  841
# Doc preprocessed:  842
# Doc preprocessed:  843
# Doc preprocessed:  844
# Doc preprocessed:  845
# Doc preprocessed:  846
# Doc preprocessed:  847
# Doc preprocessed:  848
# Doc preprocessed:  849
# Doc preprocessed:  850
# Doc preprocessed:  851
# Doc preprocessed:  852
# Doc preprocessed:  853
# Doc preprocessed:  854
# Doc preprocessed:  855
# Doc preprocessed:  856
# Doc preprocessed:  857
# Doc preprocessed:  858
# Doc preprocessed:  859
# Doc preprocessed:  860
# Doc preprocessed:  861
# Doc preprocessed:  862
# Doc preprocessed:  863
# Doc preprocessed:  864
# Doc preprocessed:  865
# Doc preprocessed:  866
# Doc preprocessed:  867
# Doc preprocessed:  868
# Doc preprocessed:  869
# Doc preprocessed:  870
# Doc preprocessed:  871
# Doc preprocessed:  872
# Doc preprocessed:  873
# Doc preprocessed:  874
# Doc preprocessed:  875
# Doc preprocessed:  876
# Doc preprocessed:  877
# Doc preprocessed:  878
# Doc preprocessed:  879
# Doc preprocessed:  880
# Doc preprocessed:  881
# Doc preprocessed:  882
# Doc preprocessed:  883
# Doc preprocessed:  884
# Doc preprocessed:  885
# Doc preprocessed:  886
# Doc preprocessed:  887
# Doc preprocessed:  888
# Doc preprocessed:  889
# Doc preprocessed:  890
# Doc preprocessed:  891
# Doc preprocessed:  892
# Doc preprocessed:  893
# Doc preprocessed:  894
# Doc preprocessed:  895
# Doc preprocessed:  896
# Doc preprocessed:  897
# Doc preprocessed:  898
# Doc preprocessed:  899
# Doc preprocessed:  900
# Doc preprocessed:  901
# Doc preprocessed:  902
# Doc preprocessed:  903
# Doc preprocessed:  904
# Doc preprocessed:  905
# Doc preprocessed:  906
# Doc preprocessed:  907
# Doc preprocessed:  908
# Doc preprocessed:  909
# Doc preprocessed:  910
# Doc preprocessed:  911
# Doc preprocessed:  912
# Doc preprocessed:  913
# Doc preprocessed:  914
# Doc preprocessed:  915
# Doc preprocessed:  916
# Doc preprocessed:  917
# Doc preprocessed:  918
# Doc preprocessed:  919
# Doc preprocessed:  920
# Doc preprocessed:  921
# Doc preprocessed:  922
# Doc preprocessed:  923
# Doc preprocessed:  924
# Doc preprocessed:  925
# Doc preprocessed:  926
# Doc preprocessed:  927
# Doc preprocessed:  928
# Doc preprocessed:  929
# Doc preprocessed:  930
# Doc preprocessed:  931
# Doc preprocessed:  932
# Doc preprocessed:  933
# Doc preprocessed:  934
# Doc preprocessed:  935
# Doc preprocessed:  936
# Doc preprocessed:  937
# Doc preprocessed:  938
# Doc preprocessed:  939
# Doc preprocessed:  940
# Doc preprocessed:  941
# Doc preprocessed:  942
# Doc preprocessed:  943
# Doc preprocessed:  944
# Doc preprocessed:  945
# Doc preprocessed:  946
# Doc preprocessed:  947
# Doc preprocessed:  948
# Doc preprocessed:  949
# Doc preprocessed:  950
# Doc preprocessed:  951
# Doc preprocessed:  952
# Doc preprocessed:  953
# Doc preprocessed:  954
# Doc preprocessed:  955
# Doc preprocessed:  956
# Doc preprocessed:  957
# Doc preprocessed:  958
# Doc preprocessed:  959
# Doc preprocessed:  960
# Doc preprocessed:  961
# Doc preprocessed:  962
# Doc preprocessed:  963
# Doc preprocessed:  964
# Doc preprocessed:  965
# Doc preprocessed:  966
# Doc preprocessed:  967
# Doc preprocessed:  968
# Doc preprocessed:  969
# Doc preprocessed:  970
# Doc preprocessed:  971
# Doc preprocessed:  972
# Doc preprocessed:  973
# Doc preprocessed:  974
# Doc preprocessed:  975
# Doc preprocessed:  976
# Doc preprocessed:  977
# Doc preprocessed:  978
# Doc preprocessed:  979
# Doc preprocessed:  980
# Doc preprocessed:  981
# Doc preprocessed:  982
# Doc preprocessed:  983
# Doc preprocessed:  984
# Doc preprocessed:  985
# Doc preprocessed:  986
# Doc preprocessed:  987
# Doc preprocessed:  988
# Doc preprocessed:  989
# Doc preprocessed:  990
# Doc preprocessed:  991
# Doc preprocessed:  992
# Doc preprocessed:  993
# Doc preprocessed:  994
# Doc preprocessed:  995
# Doc preprocessed:  996
# Doc preprocessed:  997
# Doc preprocessed:  998
# Doc preprocessed:  999
# Doc preprocessed:  1000
# Doc preprocessed:  1001
# Doc preprocessed:  1002
# Doc preprocessed:  1003
# Doc preprocessed:  1004
# Doc preprocessed:  1005
# Doc preprocessed:  1006
# Doc preprocessed:  1007
# Doc preprocessed:  1008
# Doc preprocessed:  1009
# Doc preprocessed:  1010
# Doc preprocessed:  1011
# Doc preprocessed:  1012
# Doc preprocessed:  1013
# Doc preprocessed:  1014
# Doc preprocessed:  1015
# Doc preprocessed:  1016
# Doc preprocessed:  1017
# Doc preprocessed:  1018
# Doc preprocessed:  1019
# Doc preprocessed:  1020
# Doc preprocessed:  1021
# Doc preprocessed:  1022
# Doc preprocessed:  1023
# Doc preprocessed:  1024
# Doc preprocessed:  1025
# Doc preprocessed:  1026
# Doc preprocessed:  1027
# Doc preprocessed:  1028
# Doc preprocessed:  1029
# Doc preprocessed:  1030
# Doc preprocessed:  1031
# Doc preprocessed:  1032
# Doc preprocessed:  1033
# Doc preprocessed:  1034
# Doc preprocessed:  1035
# Doc preprocessed:  1036
# Doc preprocessed:  1037
# Doc preprocessed:  1038
# Doc preprocessed:  1039
# Doc preprocessed:  1040
# Doc preprocessed:  1041
# Doc preprocessed:  1042
# Doc preprocessed:  1043
# Doc preprocessed:  1044
# Doc preprocessed:  1045
# Doc preprocessed:  1046
# Doc preprocessed:  1047
# Doc preprocessed:  1048
# Doc preprocessed:  1049
# Doc preprocessed:  1050
# Doc preprocessed:  1051
# Doc preprocessed:  1052
# Doc preprocessed:  1053
# Doc preprocessed:  1054
# Doc preprocessed:  1055
# Doc preprocessed:  1056
# Doc preprocessed:  1057
# Doc preprocessed:  1058
# Doc preprocessed:  1059
# Doc preprocessed:  1060
# Doc preprocessed:  1061
# Doc preprocessed:  1062
# Doc preprocessed:  1063
# Doc preprocessed:  1064
# Doc preprocessed:  1065
# Doc preprocessed:  1066
# Doc preprocessed:  1067
# Doc preprocessed:  1068
# Doc preprocessed:  1069
# Doc preprocessed:  1070
# Doc preprocessed:  1071
# Doc preprocessed:  1072
# Doc preprocessed:  1073
# Doc preprocessed:  1074
# Doc preprocessed:  1075
# Doc preprocessed:  1076
# Doc preprocessed:  1077
# Doc preprocessed:  1078
# Doc preprocessed:  1079
# Doc preprocessed:  1080
# Doc preprocessed:  1081
# Doc preprocessed:  1082
# Doc preprocessed:  1083
# Doc preprocessed:  1084
# Doc preprocessed:  1085
# Doc preprocessed:  1086
# Doc preprocessed:  1087
# Doc preprocessed:  1088
# Doc preprocessed:  1089
# Doc preprocessed:  1090
# Doc preprocessed:  1091
# Doc preprocessed:  1092
# Doc preprocessed:  1093
# Doc preprocessed:  1094
# Doc preprocessed:  1095
# Doc preprocessed:  1096
# Doc preprocessed:  1097
# Doc preprocessed:  1098
# Doc preprocessed:  1099
# Doc preprocessed:  1100
# Doc preprocessed:  1101
# Doc preprocessed:  1102
# Doc preprocessed:  1103
# Doc preprocessed:  1104
# Doc preprocessed:  1105
# Doc preprocessed:  1106
# Doc preprocessed:  1107
# Doc preprocessed:  1108
# Doc preprocessed:  1109
# Doc preprocessed:  1110
# Doc preprocessed:  1111
# Doc preprocessed:  1112
# Doc preprocessed:  1113
# Doc preprocessed:  1114
# Doc preprocessed:  1115
# Doc preprocessed:  1116
# Doc preprocessed:  1117
# Doc preprocessed:  1118
# Doc preprocessed:  1119
# Doc preprocessed:  1120
# Doc preprocessed:  1121
# Doc preprocessed:  1122
# Doc preprocessed:  1123
# Doc preprocessed:  1124
# Doc preprocessed:  1125
# Doc preprocessed:  1126
# Doc preprocessed:  1127
# Doc preprocessed:  1128
# Doc preprocessed:  1129
# Doc preprocessed:  1130
# Doc preprocessed:  1131
# Doc preprocessed:  1132
# Doc preprocessed:  1133
# Doc preprocessed:  1134
# Doc preprocessed:  1135
# Doc preprocessed:  1136
# Doc preprocessed:  1137
# Doc preprocessed:  1138
# Doc preprocessed:  1139
# Doc preprocessed:  1140
# Doc preprocessed:  1141
# Doc preprocessed:  1142
# Doc preprocessed:  1143
# Doc preprocessed:  1144
# Doc preprocessed:  1145
# Doc preprocessed:  1146
# Doc preprocessed:  1147
# Doc preprocessed:  1148
# Doc preprocessed:  1149
# Doc preprocessed:  1150
# Doc preprocessed:  1151
# Doc preprocessed:  1152
# Doc preprocessed:  1153
# Doc preprocessed:  1154
# Doc preprocessed:  1155
# Doc preprocessed:  1156
# Doc preprocessed:  1157
# Doc preprocessed:  1158
# Doc preprocessed:  1159
# Doc preprocessed:  1160
# Doc preprocessed:  1161
# Doc preprocessed:  1162
# Doc preprocessed:  1163
# Doc preprocessed:  1164
# Doc preprocessed:  1165
# Doc preprocessed:  1166
# Doc preprocessed:  1167
# Doc preprocessed:  1168
# Doc preprocessed:  1169
# Doc preprocessed:  1170
# Doc preprocessed:  1171
# Doc preprocessed:  1172
# Doc preprocessed:  1173
# Doc preprocessed:  1174
# Doc preprocessed:  1175
# Doc preprocessed:  1176
# Doc preprocessed:  1177
# Doc preprocessed:  1178
# Doc preprocessed:  1179
# Doc preprocessed:  1180
# Doc preprocessed:  1181
# Doc preprocessed:  1182
# Doc preprocessed:  1183
# Doc preprocessed:  1184
# Doc preprocessed:  1185
# Doc preprocessed:  1186
# Doc preprocessed:  1187
# Doc preprocessed:  1188
# Doc preprocessed:  1189
# Doc preprocessed:  1190
# Doc preprocessed:  1191
# Doc preprocessed:  1192
# Doc preprocessed:  1193
# Doc preprocessed:  1194
# Doc preprocessed:  1195
# Doc preprocessed:  1196
# Doc preprocessed:  1197
# Doc preprocessed:  1198
# Doc preprocessed:  1199
# Doc preprocessed:  1200
# Doc preprocessed:  1201
# Doc preprocessed:  1202
# Doc preprocessed:  1203
# Doc preprocessed:  1204
# Doc preprocessed:  1205
# Doc preprocessed:  1206
# Doc preprocessed:  1207
# Doc preprocessed:  1208
# Doc preprocessed:  1209
# Doc preprocessed:  1210
# Doc preprocessed:  1211
# Doc preprocessed:  1212
# Doc preprocessed:  1213
# Doc preprocessed:  1214
# Doc preprocessed:  1215
# Doc preprocessed:  1216
# Doc preprocessed:  1217
# Doc preprocessed:  1218
# Doc preprocessed:  1219
# Doc preprocessed:  1220
# Doc preprocessed:  1221
# Doc preprocessed:  1222
# Doc preprocessed:  1223
# Doc preprocessed:  1224
# Doc preprocessed:  1225
# Doc preprocessed:  1226
# Doc preprocessed:  1227
# Doc preprocessed:  1228
# Doc preprocessed:  1229
# Doc preprocessed:  1230
# Doc preprocessed:  1231
# Doc preprocessed:  1232
# Doc preprocessed:  1233
# Doc preprocessed:  1234
# Doc preprocessed:  1235
# Doc preprocessed:  1236
# Doc preprocessed:  1237
# Doc preprocessed:  1238
# Doc preprocessed:  1239
# Doc preprocessed:  1240
# Doc preprocessed:  1241
# Doc preprocessed:  1242
# Doc preprocessed:  1243
# Doc preprocessed:  1244
# Doc preprocessed:  1245
# Doc preprocessed:  1246
# Doc preprocessed:  1247
# Doc preprocessed:  1248
# Doc preprocessed:  1249
# Doc preprocessed:  1250
# Doc preprocessed:  1251
# Doc preprocessed:  1252
# Doc preprocessed:  1253
# Doc preprocessed:  1254
# Doc preprocessed:  1255
# Doc preprocessed:  1256
# Doc preprocessed:  1257
# Doc preprocessed:  1258
# Doc preprocessed:  1259
# Doc preprocessed:  1260
# Doc preprocessed:  1261
# Doc preprocessed:  1262
# Doc preprocessed:  1263
# Doc preprocessed:  1264
# Doc preprocessed:  1265
# Doc preprocessed:  1266
# Doc preprocessed:  1267
# Doc preprocessed:  1268
# Doc preprocessed:  1269
# Doc preprocessed:  1270
# Doc preprocessed:  1271
# Doc preprocessed:  1272
# Doc preprocessed:  1273
# Doc preprocessed:  1274
# Doc preprocessed:  1275
# Doc preprocessed:  1276
# Doc preprocessed:  1277
# Doc preprocessed:  1278
# Doc preprocessed:  1279
# Doc preprocessed:  1280
# Doc preprocessed:  1281
# Doc preprocessed:  1282
# Doc preprocessed:  1283
# Doc preprocessed:  1284
# Doc preprocessed:  1285
# Doc preprocessed:  1286
# Doc preprocessed:  1287
# Doc preprocessed:  1288
# Doc preprocessed:  1289
# Doc preprocessed:  1290
# Doc preprocessed:  1291
# Doc preprocessed:  1292
# Doc preprocessed:  1293
# Doc preprocessed:  1294
# Doc preprocessed:  1295
# Doc preprocessed:  1296
# Doc preprocessed:  1297
# Doc preprocessed:  1298
# Doc preprocessed:  1299
# Doc preprocessed:  1300
# Doc preprocessed:  1301
# Doc preprocessed:  1302
# Doc preprocessed:  1303
# Doc preprocessed:  1304
# Doc preprocessed:  1305
# Doc preprocessed:  1306
# Doc preprocessed:  1307
# Doc preprocessed:  1308
# Doc preprocessed:  1309
# Doc preprocessed:  1310
# Doc preprocessed:  1311
# Doc preprocessed:  1312
# Doc preprocessed:  1313
# Doc preprocessed:  1314
# Doc preprocessed:  1315
# Doc preprocessed:  1316
# Doc preprocessed:  1317
# Doc preprocessed:  1318
# Doc preprocessed:  1319
# Doc preprocessed:  1320
# Doc preprocessed:  1321
# Doc preprocessed:  1322
# Doc preprocessed:  1323
# Doc preprocessed:  1324
# Doc preprocessed:  1325
# Doc preprocessed:  1326
# Doc preprocessed:  1327
# Doc preprocessed:  1328
# Doc preprocessed:  1329
# Doc preprocessed:  1330
# Doc preprocessed:  1331
# Doc preprocessed:  1332
# Doc preprocessed:  1333
# Doc preprocessed:  1334
# Doc preprocessed:  1335
# Doc preprocessed:  1336
# Doc preprocessed:  1337
# Doc preprocessed:  1338
# Doc preprocessed:  1339
# Doc preprocessed:  1340
# Doc preprocessed:  1341
# Doc preprocessed:  1342
# Doc preprocessed:  1343
# Doc preprocessed:  1344
# Doc preprocessed:  1345
# Doc preprocessed:  1346
# Doc preprocessed:  1347
# Doc preprocessed:  1348
# Doc preprocessed:  1349
# Doc preprocessed:  1350
# Doc preprocessed:  1351
# Doc preprocessed:  1352
# Doc preprocessed:  1353
# Doc preprocessed:  1354
# Doc preprocessed:  1355
# Doc preprocessed:  1356
# Doc preprocessed:  1357
# Doc preprocessed:  1358
# Doc preprocessed:  1359
# Doc preprocessed:  1360
# Doc preprocessed:  1361
# Doc preprocessed:  1362
# Doc preprocessed:  1363
# Doc preprocessed:  1364
# Doc preprocessed:  1365
# Doc preprocessed:  1366
# Doc preprocessed:  1367
# Doc preprocessed:  1368
# Doc preprocessed:  1369
# Doc preprocessed:  1370
# Doc preprocessed:  1371
# Doc preprocessed:  1372
# Doc preprocessed:  1373
# Doc preprocessed:  1374
# Doc preprocessed:  1375
# Doc preprocessed:  1376
# Doc preprocessed:  1377
# Doc preprocessed:  1378
# Doc preprocessed:  1379
# Doc preprocessed:  1380
# Doc preprocessed:  1381
# Doc preprocessed:  1382
# Doc preprocessed:  1383
# Doc preprocessed:  1384
# Doc preprocessed:  1385
# Doc preprocessed:  1386
# Doc preprocessed:  1387
# Doc preprocessed:  1388
# Doc preprocessed:  1389
# Doc preprocessed:  1390
# Doc preprocessed:  1391
# Doc preprocessed:  1392
# Doc preprocessed:  1393
# Doc preprocessed:  1394
# Doc preprocessed:  1395
# Doc preprocessed:  1396
# Doc preprocessed:  1397
# Doc preprocessed:  1398
# Doc preprocessed:  1399
# Doc preprocessed:  1400
# Doc preprocessed:  1401
# Doc preprocessed:  1402
# Doc preprocessed:  1403
# Doc preprocessed:  1404
# Doc preprocessed:  1405
# Doc preprocessed:  1406
# Doc preprocessed:  1407
# Doc preprocessed:  1408
# Doc preprocessed:  1409
# Doc preprocessed:  1410
# Doc preprocessed:  1411
# Doc preprocessed:  1412
# Doc preprocessed:  1413
# Doc preprocessed:  1414
# Doc preprocessed:  1415
# Doc preprocessed:  1416
# Doc preprocessed:  1417
# Doc preprocessed:  1418
# Doc preprocessed:  1419
# Doc preprocessed:  1420
# Doc preprocessed:  1421
# Doc preprocessed:  1422
# Doc preprocessed:  1423
# Doc preprocessed:  1424
# Doc preprocessed:  1425
# Doc preprocessed:  1426
# Doc preprocessed:  1427
# Doc preprocessed:  1428
# Doc preprocessed:  1429
# Doc preprocessed:  1430
# Doc preprocessed:  1431
# Doc preprocessed:  1432
# Doc preprocessed:  1433
# Doc preprocessed:  1434
# Doc preprocessed:  1435
# Doc preprocessed:  1436
# Doc preprocessed:  1437
# Doc preprocessed:  1438
# Doc preprocessed:  1439
# Doc preprocessed:  1440
# Doc preprocessed:  1441
# Doc preprocessed:  1442
# Doc preprocessed:  1443
# Doc preprocessed:  1444
# Doc preprocessed:  1445
# Doc preprocessed:  1446
# Doc preprocessed:  1447
# Doc preprocessed:  1448
# Doc preprocessed:  1449
# Doc preprocessed:  1450
# Doc preprocessed:  1451
# Doc preprocessed:  1452
# Doc preprocessed:  1453
# Doc preprocessed:  1454
# Doc preprocessed:  1455
# Doc preprocessed:  1456
# Doc preprocessed:  1457
# Doc preprocessed:  1458
# Doc preprocessed:  1459
# Doc preprocessed:  1460
# Doc preprocessed:  1461
# Doc preprocessed:  1462
# Doc preprocessed:  1463
# Doc preprocessed:  1464
# Doc preprocessed:  1465
# Doc preprocessed:  1466
# Doc preprocessed:  1467
# Doc preprocessed:  1468
# Doc preprocessed:  1469
# Doc preprocessed:  1470
# Doc preprocessed:  1471
# Doc preprocessed:  1472
# Doc preprocessed:  1473
# Doc preprocessed:  1474
# Doc preprocessed:  1475
# Doc preprocessed:  1476
# Doc preprocessed:  1477
# Doc preprocessed:  1478
# Doc preprocessed:  1479
# Doc preprocessed:  1480
# Doc preprocessed:  1481
# Doc preprocessed:  1482
# Doc preprocessed:  1483
# Doc preprocessed:  1484
# Doc preprocessed:  1485
# Doc preprocessed:  1486
# Doc preprocessed:  1487
# Doc preprocessed:  1488
# Doc preprocessed:  1489
# Doc preprocessed:  1490
# Doc preprocessed:  1491
# Doc preprocessed:  1492
# Doc preprocessed:  1493
# Doc preprocessed:  1494
# Doc preprocessed:  1495
# Doc preprocessed:  1496
# Doc preprocessed:  1497
# Doc preprocessed:  1498
# Doc preprocessed:  1499
# Doc preprocessed:  1500
# Doc preprocessed:  1501
# Doc preprocessed:  1502
# Doc preprocessed:  1503
# Doc preprocessed:  1504
# Doc preprocessed:  1505
# Doc preprocessed:  1506
# Doc preprocessed:  1507
# Doc preprocessed:  1508
# Doc preprocessed:  1509
# Doc preprocessed:  1510
# Doc preprocessed:  1511
# Doc preprocessed:  1512
# Doc preprocessed:  1513
# Doc preprocessed:  1514
# Doc preprocessed:  1515
# Doc preprocessed:  1516
# Doc preprocessed:  1517
# Doc preprocessed:  1518
# Doc preprocessed:  1519
# Doc preprocessed:  1520
# Doc preprocessed:  1521
# Doc preprocessed:  1522
# Doc preprocessed:  1523
# Doc preprocessed:  1524
# Doc preprocessed:  1525
# Doc preprocessed:  1526
# Doc preprocessed:  1527
# Doc preprocessed:  1528
# Doc preprocessed:  1529
# Doc preprocessed:  1530
# Doc preprocessed:  1531
# Doc preprocessed:  1532
# Doc preprocessed:  1533
# Doc preprocessed:  1534
# Doc preprocessed:  1535
# Doc preprocessed:  1536
# Doc preprocessed:  1537
# Doc preprocessed:  1538
# Doc preprocessed:  1539
# Doc preprocessed:  1540
# Doc preprocessed:  1541
# Doc preprocessed:  1542
# Doc preprocessed:  1543
# Doc preprocessed:  1544
# Doc preprocessed:  1545
# Doc preprocessed:  1546
# Doc preprocessed:  1547
# Doc preprocessed:  1548
# Doc preprocessed:  1549
# Doc preprocessed:  1550
# Doc preprocessed:  1551
# Doc preprocessed:  1552
# Doc preprocessed:  1553
# Doc preprocessed:  1554
# Doc preprocessed:  1555
# Doc preprocessed:  1556
# Doc preprocessed:  1557
# Doc preprocessed:  1558
# Doc preprocessed:  1559
# Doc preprocessed:  1560
# Doc preprocessed:  1561
# Doc preprocessed:  1562
# Doc preprocessed:  1563
# Doc preprocessed:  1564
# Doc preprocessed:  1565
# Doc preprocessed:  1566
# Doc preprocessed:  1567
# Doc preprocessed:  1568
# Doc preprocessed:  1569
# Doc preprocessed:  1570
# Doc preprocessed:  1571
# Doc preprocessed:  1572
# Doc preprocessed:  1573
# Doc preprocessed:  1574
# Doc preprocessed:  1575
# Doc preprocessed:  1576
# Doc preprocessed:  1577
# Doc preprocessed:  1578
# Doc preprocessed:  1579
# Doc preprocessed:  1580
# Doc preprocessed:  1581
# Doc preprocessed:  1582
# Doc preprocessed:  1583
# Doc preprocessed:  1584
# Doc preprocessed:  1585
# Doc preprocessed:  1586
# Doc preprocessed:  1587
# Doc preprocessed:  1588
# Doc preprocessed:  1589
# Doc preprocessed:  1590
# Doc preprocessed:  1591
# Doc preprocessed:  1592
# Doc preprocessed:  1593
# Doc preprocessed:  1594
# Doc preprocessed:  1595
# Doc preprocessed:  1596
# Doc preprocessed:  1597
# Doc preprocessed:  1598
# Doc preprocessed:  1599
# Doc preprocessed:  1600
# Doc preprocessed:  1601
# Doc preprocessed:  1602
# Doc preprocessed:  1603
# Doc preprocessed:  1604
# Doc preprocessed:  1605
# Doc preprocessed:  1606
# Doc preprocessed:  1607
# Doc preprocessed:  1608
# Doc preprocessed:  1609
# Doc preprocessed:  1610
# Doc preprocessed:  1611
# Doc preprocessed:  1612
# Doc preprocessed:  1613
# Doc preprocessed:  1614
# Doc preprocessed:  1615
# Doc preprocessed:  1616
# Doc preprocessed:  1617
# Doc preprocessed:  1618
# Doc preprocessed:  1619
# Doc preprocessed:  1620
# Doc preprocessed:  1621
# Doc preprocessed:  1622
# Doc preprocessed:  1623
# Doc preprocessed:  1624
# Doc preprocessed:  1625
# Doc preprocessed:  1626
# Doc preprocessed:  1627
# Doc preprocessed:  1628
# Doc preprocessed:  1629
# Doc preprocessed:  1630
# Doc preprocessed:  1631
# Doc preprocessed:  1632
# Doc preprocessed:  1633
# Doc preprocessed:  1634
# Doc preprocessed:  1635
# Doc preprocessed:  1636
# Doc preprocessed:  1637
# Doc preprocessed:  1638
# Doc preprocessed:  1639
# Doc preprocessed:  1640
# Doc preprocessed:  1641
# Doc preprocessed:  1642
# Doc preprocessed:  1643
# Doc preprocessed:  1644
# Doc preprocessed:  1645
# Doc preprocessed:  1646
# Doc preprocessed:  1647
# Doc preprocessed:  1648
# Doc preprocessed:  1649
# Doc preprocessed:  1650
# Doc preprocessed:  1651
# Doc preprocessed:  1652
# Doc preprocessed:  1653
# Doc preprocessed:  1654
# Doc preprocessed:  1655
# Doc preprocessed:  1656
# Doc preprocessed:  1657
# Doc preprocessed:  1658
# Doc preprocessed:  1659
# Doc preprocessed:  1660
# Doc preprocessed:  1661
# Doc preprocessed:  1662
# Doc preprocessed:  1663
# Doc preprocessed:  1664
# Doc preprocessed:  1665
# Doc preprocessed:  1666
# Doc preprocessed:  1667
# Doc preprocessed:  1668
# Doc preprocessed:  1669
# Doc preprocessed:  1670
# Doc preprocessed:  1671
# Doc preprocessed:  1672
# Doc preprocessed:  1673
# Doc preprocessed:  1674
# Doc preprocessed:  1675
# Doc preprocessed:  1676
# Doc preprocessed:  1677
# Doc preprocessed:  1678
# Doc preprocessed:  1679
# Doc preprocessed:  1680
# Doc preprocessed:  1681
# Doc preprocessed:  1682
# Doc preprocessed:  1683
# Doc preprocessed:  1684
# Doc preprocessed:  1685
# Doc preprocessed:  1686
# Doc preprocessed:  1687
# Doc preprocessed:  1688
# Doc preprocessed:  1689
# Doc preprocessed:  1690
# Doc preprocessed:  1691
# Doc preprocessed:  1692
# Doc preprocessed:  1693
# Doc preprocessed:  1694
# Doc preprocessed:  1695
# Doc preprocessed:  1696
# Doc preprocessed:  1697
# Doc preprocessed:  1698
# Doc preprocessed:  1699
# Doc preprocessed:  1700
# Doc preprocessed:  1701
# Doc preprocessed:  1702
# Doc preprocessed:  1703
# Doc preprocessed:  1704
# Doc preprocessed:  1705
# Doc preprocessed:  1706
# Doc preprocessed:  1707
# Doc preprocessed:  1708
# Doc preprocessed:  1709
# Doc preprocessed:  1710
# Doc preprocessed:  1711
# Doc preprocessed:  1712
# Doc preprocessed:  1713
# Doc preprocessed:  1714
# Doc preprocessed:  1715
# Doc preprocessed:  1716
# Doc preprocessed:  1717
# Doc preprocessed:  1718
# Doc preprocessed:  1719
# Doc preprocessed:  1720
# Doc preprocessed:  1721
# Doc preprocessed:  1722
# Doc preprocessed:  1723
# Doc preprocessed:  1724
# Doc preprocessed:  1725
# Doc preprocessed:  1726
# Doc preprocessed:  1727
# Doc preprocessed:  1728
# Doc preprocessed:  1729
# Doc preprocessed:  1730
# Doc preprocessed:  1731
# Doc preprocessed:  1732
# Doc preprocessed:  1733
# Doc preprocessed:  1734
# Doc preprocessed:  1735
# Doc preprocessed:  1736
# Doc preprocessed:  1737
# Doc preprocessed:  1738
# Doc preprocessed:  1739
# Doc preprocessed:  1740
# Doc preprocessed:  1741
# Doc preprocessed:  1742
# Doc preprocessed:  1743
# Doc preprocessed:  1744
# Doc preprocessed:  1745
# Doc preprocessed:  1746
# Doc preprocessed:  1747
# Doc preprocessed:  1748
# Doc preprocessed:  1749
# Doc preprocessed:  1750
# Doc preprocessed:  1751
# Doc preprocessed:  1752
# Doc preprocessed:  1753
# Doc preprocessed:  1754
# Doc preprocessed:  1755
# Doc preprocessed:  1756
# Doc preprocessed:  1757
# Doc preprocessed:  1758
# Doc preprocessed:  1759
# Doc preprocessed:  1760
# Doc preprocessed:  1761
# Doc preprocessed:  1762
# Doc preprocessed:  1763
# Doc preprocessed:  1764
# Doc preprocessed:  1765
# Doc preprocessed:  1766
# Doc preprocessed:  1767
# Doc preprocessed:  1768
# Doc preprocessed:  1769
# Doc preprocessed:  1770
# Doc preprocessed:  1771
# Doc preprocessed:  1772
# Doc preprocessed:  1773
# Doc preprocessed:  1774
# Doc preprocessed:  1775
# Doc preprocessed:  1776
# Doc preprocessed:  1777
# Doc preprocessed:  1778
# Doc preprocessed:  1779
# Doc preprocessed:  1780
# Doc preprocessed:  1781
# Doc preprocessed:  1782
# Doc preprocessed:  1783
# Doc preprocessed:  1784
# Doc preprocessed:  1785
# Doc preprocessed:  1786
# Doc preprocessed:  1787
# Doc preprocessed:  1788
# Doc preprocessed:  1789
# Doc preprocessed:  1790
# Doc preprocessed:  1791
# Doc preprocessed:  1792
# Doc preprocessed:  1793
# Doc preprocessed:  1794
# Doc preprocessed:  1795
# Doc preprocessed:  1796
# Doc preprocessed:  1797
# Doc preprocessed:  1798
# Doc preprocessed:  1799
# Doc preprocessed:  1800
# Doc preprocessed:  1801
# Doc preprocessed:  1802
# Doc preprocessed:  1803
# Doc preprocessed:  1804
# Doc preprocessed:  1805
# Doc preprocessed:  1806
# Doc preprocessed:  1807
# Doc preprocessed:  1808
# Doc preprocessed:  1809
# Doc preprocessed:  1810
# Doc preprocessed:  1811
# Doc preprocessed:  1812
# Doc preprocessed:  1813
# Doc preprocessed:  1814
# Doc preprocessed:  1815
# Doc preprocessed:  1816
# Doc preprocessed:  1817
# Doc preprocessed:  1818
# Doc preprocessed:  1819
# Doc preprocessed:  1820
# Doc preprocessed:  1821
# Doc preprocessed:  1822
# Doc preprocessed:  1823
# Doc preprocessed:  1824
# Doc preprocessed:  1825
# Doc preprocessed:  1826
# Doc preprocessed:  1827
# Doc preprocessed:  1828
# Doc preprocessed:  1829
# Doc preprocessed:  1830
# Doc preprocessed:  1831
# Doc preprocessed:  1832
# Doc preprocessed:  1833
# Doc preprocessed:  1834
# Doc preprocessed:  1835
# Doc preprocessed:  1836
# Doc preprocessed:  1837
# Doc preprocessed:  1838
# Doc preprocessed:  1839
# Doc preprocessed:  1840
# Doc preprocessed:  1841
# Doc preprocessed:  1842
# Doc preprocessed:  1843
# Doc preprocessed:  1844
# Doc preprocessed:  1845
# Doc preprocessed:  1846
# Doc preprocessed:  1847
# Doc preprocessed:  1848
# Doc preprocessed:  1849
# Doc preprocessed:  1850
# Doc preprocessed:  1851
# Doc preprocessed:  1852
# Doc preprocessed:  1853
# Doc preprocessed:  1854
# Doc preprocessed:  1855
# Doc preprocessed:  1856
# Doc preprocessed:  1857
# Doc preprocessed:  1858
# Doc preprocessed:  1859
# Doc preprocessed:  1860
# Doc preprocessed:  1861
# Doc preprocessed:  1862
# Doc preprocessed:  1863
# Doc preprocessed:  1864
# Doc preprocessed:  1865
# Doc preprocessed:  1866
# Doc preprocessed:  1867
# Doc preprocessed:  1868
# Doc preprocessed:  1869
# Doc preprocessed:  1870
# Doc preprocessed:  1871
# Doc preprocessed:  1872
# Doc preprocessed:  1873
# Doc preprocessed:  1874
# Doc preprocessed:  1875
# Doc preprocessed:  1876
# Doc preprocessed:  1877
# Doc preprocessed:  1878
# Doc preprocessed:  1879
# Doc preprocessed:  1880
# Doc preprocessed:  1881
# Doc preprocessed:  1882
# Doc preprocessed:  1883
# Doc preprocessed:  1884
# Doc preprocessed:  1885
# Doc preprocessed:  1886
# Doc preprocessed:  1887
# Doc preprocessed:  1888
# Doc preprocessed:  1889
# Doc preprocessed:  1890
# Doc preprocessed:  1891
# Doc preprocessed:  1892
# Doc preprocessed:  1893
# Doc preprocessed:  1894
# Doc preprocessed:  1895
# Doc preprocessed:  1896
# Doc preprocessed:  1897
# Doc preprocessed:  1898
# Doc preprocessed:  1899
# Doc preprocessed:  1900
# Doc preprocessed:  1901
# Doc preprocessed:  1902
# Doc preprocessed:  1903
# Doc preprocessed:  1904
# Doc preprocessed:  1905
# Doc preprocessed:  1906
# Doc preprocessed:  1907
# Doc preprocessed:  1908
# Doc preprocessed:  1909
# Doc preprocessed:  1910
# Doc preprocessed:  1911
# Doc preprocessed:  1912
# Doc preprocessed:  1913
# Doc preprocessed:  1914
# Doc preprocessed:  1915
# Doc preprocessed:  1916
# Doc preprocessed:  1917
# Doc preprocessed:  1918
# Doc preprocessed:  1919
# Doc preprocessed:  1920
# Doc preprocessed:  1921
# Doc preprocessed:  1922
# Doc preprocessed:  1923
# Doc preprocessed:  1924
# Doc preprocessed:  1925
# Doc preprocessed:  1926
# Doc preprocessed:  1927
# Doc preprocessed:  1928
# Doc preprocessed:  1929
# Doc preprocessed:  1930
# Doc preprocessed:  1931
# Doc preprocessed:  1932
# Doc preprocessed:  1933
# Doc preprocessed:  1934
# Doc preprocessed:  1935
# Doc preprocessed:  1936
# Doc preprocessed:  1937
# Doc preprocessed:  1938
# Doc preprocessed:  1939
# Doc preprocessed:  1940
# Doc preprocessed:  1941
# Doc preprocessed:  1942
# Doc preprocessed:  1943
# Doc preprocessed:  1944
# Doc preprocessed:  1945
# Doc preprocessed:  1946
# Doc preprocessed:  1947
# Doc preprocessed:  1948
# Doc preprocessed:  1949
# Doc preprocessed:  1950
# Doc preprocessed:  1951
# Doc preprocessed:  1952
# Doc preprocessed:  1953
# Doc preprocessed:  1954
# Doc preprocessed:  1955
# Doc preprocessed:  1956
# Doc preprocessed:  1957
# Doc preprocessed:  1958
# Doc preprocessed:  1959
# Doc preprocessed:  1960
# Doc preprocessed:  1961
# Doc preprocessed:  1962
# Doc preprocessed:  1963
# Doc preprocessed:  1964
# Doc preprocessed:  1965
# Doc preprocessed:  1966
# Doc preprocessed:  1967
# Doc preprocessed:  1968
# Doc preprocessed:  1969
# Doc preprocessed:  1970
# Doc preprocessed:  1971
# Doc preprocessed:  1972
# Doc preprocessed:  1973
# Doc preprocessed:  1974
# Doc preprocessed:  1975
# Doc preprocessed:  1976
# Doc preprocessed:  1977
# Doc preprocessed:  1978
# Doc preprocessed:  1979
# Doc preprocessed:  1980
# Doc preprocessed:  1981
# Doc preprocessed:  1982
# Doc preprocessed:  1983
# Doc preprocessed:  1984
# Doc preprocessed:  1985
# Doc preprocessed:  1986
# Doc preprocessed:  1987
# Doc preprocessed:  1988
# Doc preprocessed:  1989
# Doc preprocessed:  1990
# Doc preprocessed:  1991
# Doc preprocessed:  1992
# Doc preprocessed:  1993
# Doc preprocessed:  1994
# Doc preprocessed:  1995
# Doc preprocessed:  1996
# Doc preprocessed:  1997
# Doc preprocessed:  1998
# Doc preprocessed:  1999
# Doc preprocessed:  2000
# Doc preprocessed:  2001
# Doc preprocessed:  2002
# Doc preprocessed:  2003
# Doc preprocessed:  2004
# Doc preprocessed:  2005
# Doc preprocessed:  2006
# Doc preprocessed:  2007
# Doc preprocessed:  2008
# Doc preprocessed:  2009
# Doc preprocessed:  2010
# Doc preprocessed:  2011
# Doc preprocessed:  2012
# Doc preprocessed:  2013
# Doc preprocessed:  2014
# Doc preprocessed:  2015
# Doc preprocessed:  2016
# Doc preprocessed:  2017
# Doc preprocessed:  2018
# Doc preprocessed:  2019
# Doc preprocessed:  2020
# Doc preprocessed:  2021
# Doc preprocessed:  2022
# Doc preprocessed:  2023
# Doc preprocessed:  2024
# Doc preprocessed:  2025
# Doc preprocessed:  2026
# Doc preprocessed:  2027
# Doc preprocessed:  2028
# Doc preprocessed:  2029
# Doc preprocessed:  2030
# Doc preprocessed:  2031
# Doc preprocessed:  2032
# Doc preprocessed:  2033
# Doc preprocessed:  2034
# Doc preprocessed:  2035
# Doc preprocessed:  2036
# Doc preprocessed:  2037
# Doc preprocessed:  2038
# Doc preprocessed:  2039
# Doc preprocessed:  2040
# Doc preprocessed:  2041
# Doc preprocessed:  2042
# Doc preprocessed:  2043
# Doc preprocessed:  2044
# ...
# Doc preprocessed:  4050
# Doc preprocessed:  4051
# Doc preprocessed:  4052
# Doc preprocessed:  4053
# Doc preprocessed:  4054
# Doc preprocessed:  4055
# Doc preprocessed:  4056
# Doc preprocessed:  4057
# Doc preprocessed:  4058
# Doc preprocessed:  4059
# Doc preprocessed:  4060
# Doc preprocessed:  4061
# Doc preprocessed:  4062
# Doc preprocessed:  4063
# Doc preprocessed:  4064
# Doc preprocessed:  4065
# Doc preprocessed:  4066
# Doc preprocessed:  4067
# Doc preprocessed:  4068
# Doc preprocessed:  4069
# Doc preprocessed:  4070
# Doc preprocessed:  4071
# Doc preprocessed:  4072
# Doc preprocessed:  4073
# Doc preprocessed:  4074
# Doc preprocessed:  4075
# Doc preprocessed:  4076
# Doc preprocessed:  4077
# Doc preprocessed:  4078
# Doc preprocessed:  4079
# Doc preprocessed:  4080
# Doc preprocessed:  4081
# Doc preprocessed:  4082
# Doc preprocessed:  4083
# Doc preprocessed:  4084
# Doc preprocessed:  4085
# Doc preprocessed:  4086
# Doc preprocessed:  4087
# Doc preprocessed:  4088
# Doc preprocessed:  4089
# Doc preprocessed:  4090
# Doc preprocessed:  4091
# Doc preprocessed:  4092
# Doc preprocessed:  4093
# Doc preprocessed:  4094
# Doc preprocessed:  4095
# Doc preprocessed:  4096
# Doc preprocessed:  4097
# Doc preprocessed:  4098
# Doc preprocessed:  4099
# Doc preprocessed:  4100
# Doc preprocessed:  4101
# Doc preprocessed:  4102
# Doc preprocessed:  4103
# Doc preprocessed:  4104
# Doc preprocessed:  4105
# Doc preprocessed:  4106
# Doc preprocessed:  4107
# Doc preprocessed:  4108
# Doc preprocessed:  4109
# Doc preprocessed:  4110
# Doc preprocessed:  4111
# Doc preprocessed:  4112
# Doc preprocessed:  4113
# Doc preprocessed:  4114
# Doc preprocessed:  4115
# Doc preprocessed:  4116
# Doc preprocessed:  4117
# Doc preprocessed:  4118
# Doc preprocessed:  4119
# Doc preprocessed:  4120
# Doc preprocessed:  4121
# Doc preprocessed:  4122
# Doc preprocessed:  4123
# Doc preprocessed:  4124
# Doc preprocessed:  4125
# Doc preprocessed:  4126
# Doc preprocessed:  4127
# Doc preprocessed:  4128
# Doc preprocessed:  4129
# Doc preprocessed:  4130
# Doc preprocessed:  4131
# Doc preprocessed:  4132
# Doc preprocessed:  4133
# Doc preprocessed:  4134
# Doc preprocessed:  4135
# Doc preprocessed:  4136
# Doc preprocessed:  4137
# Doc preprocessed:  4138
# Doc preprocessed:  4139
# Doc preprocessed:  4140
# Doc preprocessed:  4141
# Doc preprocessed:  4142
# Doc preprocessed:  4143
# Doc preprocessed:  4144
# Doc preprocessed:  4145
# Doc preprocessed:  4146
# Doc preprocessed:  4147
# Doc preprocessed:  4148
# Doc preprocessed:  4149
# Doc preprocessed:  4150
# Doc preprocessed:  4151
# Doc preprocessed:  4152
# Doc preprocessed:  4153
# Doc preprocessed:  4154
# Doc preprocessed:  4155
# Doc preprocessed:  4156
# Doc preprocessed:  4157
# Doc preprocessed:  4158
# Doc preprocessed:  4159
# Doc preprocessed:  4160
# Doc preprocessed:  4161
# Doc preprocessed:  4162
# Doc preprocessed:  4163
# Doc preprocessed:  4164
# Doc preprocessed:  4165
# Doc preprocessed:  4166
# Doc preprocessed:  4167
# Doc preprocessed:  4168
# Doc preprocessed:  4169
# Doc preprocessed:  4170
# Doc preprocessed:  4171
# Doc preprocessed:  4172
# Doc preprocessed:  4173
# Doc preprocessed:  4174
# Doc preprocessed:  4175
# Doc preprocessed:  4176
# Doc preprocessed:  4177
# Doc preprocessed:  4178
# Doc preprocessed:  4179
# Doc preprocessed:  4180
# Doc preprocessed:  4181
# Doc preprocessed:  4182
# Doc preprocessed:  4183
# Doc preprocessed:  4184
# Doc preprocessed:  4185
# Doc preprocessed:  4186
# Doc preprocessed:  4187
# Doc preprocessed:  4188
# Doc preprocessed:  4189
# Doc preprocessed:  4190
# Doc preprocessed:  4191
# Doc preprocessed:  4192
# Doc preprocessed:  4193
# Doc preprocessed:  4194
# Doc preprocessed:  4195
# Doc preprocessed:  4196
# Doc preprocessed:  4197
# Doc preprocessed:  4198
# Doc preprocessed:  4199
# Doc preprocessed:  4200
# Doc preprocessed:  4201
# Doc preprocessed:  4202
# Doc preprocessed:  4203
# Doc preprocessed:  4204
# Doc preprocessed:  4205
# Doc preprocessed:  4206
# Doc preprocessed:  4207
# Doc preprocessed:  4208
# Doc preprocessed:  4209
# Doc preprocessed:  4210
# Doc preprocessed:  4211
# Doc preprocessed:  4212
# Doc preprocessed:  4213
# Doc preprocessed:  4214
# Doc preprocessed:  4215
# Doc preprocessed:  4216
# Doc preprocessed:  4217
# Doc preprocessed:  4218
# Doc preprocessed:  4219
# Doc preprocessed:  4220
# Doc preprocessed:  4221
# Doc preprocessed:  4222
# Doc preprocessed:  4223
# Doc preprocessed:  4224
# Doc preprocessed:  4225
# Doc preprocessed:  4226
# Doc preprocessed:  4227
# Doc preprocessed:  4228
# Doc preprocessed:  4229
# Doc preprocessed:  4230
# Doc preprocessed:  4231
# Doc preprocessed:  4232
# Doc preprocessed:  4233
# Doc preprocessed:  4234
# Doc preprocessed:  4235
# Doc preprocessed:  4236
# Doc preprocessed:  4237
# Doc preprocessed:  4238
# Doc preprocessed:  4239
# Doc preprocessed:  4240
# Doc preprocessed:  4241
# Doc preprocessed:  4242
# Doc preprocessed:  4243
# Doc preprocessed:  4244
# Doc preprocessed:  4245
# Doc preprocessed:  4246
# Doc preprocessed:  4247
# Doc preprocessed:  4248
# Doc preprocessed:  4249
# Doc preprocessed:  4250
# Doc preprocessed:  4251
# Doc preprocessed:  4252
# Doc preprocessed:  4253
# Doc preprocessed:  4254
# Doc preprocessed:  4255
# Doc preprocessed:  4256
# Doc preprocessed:  4257
# Doc preprocessed:  4258
# Doc preprocessed:  4259
# Doc preprocessed:  4260
# Doc preprocessed:  4261
# Doc preprocessed:  4262
# Doc preprocessed:  4263
# Doc preprocessed:  4264
# Doc preprocessed:  4265
# Doc preprocessed:  4266
# Doc preprocessed:  4267
# Doc preprocessed:  4268
# Doc preprocessed:  4269
# Doc preprocessed:  4270
# Doc preprocessed:  4271
# Doc preprocessed:  4272
# Doc preprocessed:  4273
# Doc preprocessed:  4274
# Doc preprocessed:  4275
# Doc preprocessed:  4276
# Doc preprocessed:  4277
# Doc preprocessed:  4278
# Doc preprocessed:  4279
# Doc preprocessed:  4280
# Doc preprocessed:  4281
# Doc preprocessed:  4282
# Doc preprocessed:  4283
# Doc preprocessed:  4284
# Doc preprocessed:  4285
# Doc preprocessed:  4286
# Doc preprocessed:  4287
# Doc preprocessed:  4288
# Doc preprocessed:  4289
# Doc preprocessed:  4290
# Doc preprocessed:  4291
# Doc preprocessed:  4292
# Doc preprocessed:  4293
# Doc preprocessed:  4294
# Doc preprocessed:  4295
# Doc preprocessed:  4296
# Doc preprocessed:  4297
# Doc preprocessed:  4298
# Doc preprocessed:  4299
# Doc preprocessed:  4300
# Doc preprocessed:  4301
# Doc preprocessed:  4302
# Doc preprocessed:  4303
# Doc preprocessed:  4304
# Doc preprocessed:  4305
# Doc preprocessed:  4306
# Doc preprocessed:  4307
# Doc preprocessed:  4308
# Doc preprocessed:  4309
# Doc preprocessed:  4310
# Doc preprocessed:  4311
# Doc preprocessed:  4312
# Doc preprocessed:  4313
# Doc preprocessed:  4314
# Doc preprocessed:  4315
# Doc preprocessed:  4316
# Doc preprocessed:  4317
# Doc preprocessed:  4318
# Doc preprocessed:  4319
# Doc preprocessed:  4320
# Doc preprocessed:  4321
# Doc preprocessed:  4322
# Doc preprocessed:  4323
# Doc preprocessed:  4324
# Doc preprocessed:  4325
# Doc preprocessed:  4326
# Doc preprocessed:  4327
# Doc preprocessed:  4328
# Doc preprocessed:  4329
# Doc preprocessed:  4330
# Doc preprocessed:  4331
# Doc preprocessed:  4332
# Doc preprocessed:  4333
# Doc preprocessed:  4334
# Doc preprocessed:  4335
# Doc preprocessed:  4336
# Doc preprocessed:  4337
# Doc preprocessed:  4338
# Doc preprocessed:  4339
# Doc preprocessed:  4340
# Doc preprocessed:  4341
# Doc preprocessed:  4342
# Doc preprocessed:  4343
# Doc preprocessed:  4344
# Doc preprocessed:  4345
# Doc preprocessed:  4346
# Doc preprocessed:  4347
# Doc preprocessed:  4348
# Doc preprocessed:  4349
# Doc preprocessed:  4350
# Doc preprocessed:  4351
# Doc preprocessed:  4352
# Doc preprocessed:  4353
# Doc preprocessed:  4354
# Doc preprocessed:  4355
# Doc preprocessed:  4356
# Doc preprocessed:  4357
# Doc preprocessed:  4358
# Doc preprocessed:  4359
# Doc preprocessed:  4360
# Doc preprocessed:  4361
# Doc preprocessed:  4362
# Doc preprocessed:  4363
# Doc preprocessed:  4364
# Doc preprocessed:  4365
# Doc preprocessed:  4366
# Doc preprocessed:  4367
# Doc preprocessed:  4368
# Doc preprocessed:  4369
# Doc preprocessed:  4370
# Doc preprocessed:  4371
# Doc preprocessed:  4372
# Doc preprocessed:  4373
# Doc preprocessed:  4374
# Doc preprocessed:  4375
# Doc preprocessed:  4376
# Doc preprocessed:  4377
# Doc preprocessed:  4378
# Doc preprocessed:  4379
# Doc preprocessed:  4380
# Doc preprocessed:  4381
# Doc preprocessed:  4382
# Doc preprocessed:  4383
# Doc preprocessed:  4384
# Doc preprocessed:  4385
# Doc preprocessed:  4386
# Doc preprocessed:  4387
# Doc preprocessed:  4388
# Doc preprocessed:  4389
# Doc preprocessed:  4390
# Doc preprocessed:  4391
# Doc preprocessed:  4392
# Doc preprocessed:  4393
# Doc preprocessed:  4394
# Doc preprocessed:  4395
# Doc preprocessed:  4396
# Doc preprocessed:  4397
# Doc preprocessed:  4398
# Doc preprocessed:  4399
# Doc preprocessed:  4400
# Doc preprocessed:  4401
# Doc preprocessed:  4402
# Doc preprocessed:  4403
# Doc preprocessed:  4404
# Doc preprocessed:  4405
# Doc preprocessed:  4406
# Doc preprocessed:  4407
# Doc preprocessed:  4408
# Doc preprocessed:  4409
# Doc preprocessed:  4410
# Doc preprocessed:  4411
# Doc preprocessed:  4412
# Doc preprocessed:  4413
# Doc preprocessed:  4414
# Doc preprocessed:  4415
# Doc preprocessed:  4416
# Doc preprocessed:  4417
# Doc preprocessed:  4418
# Doc preprocessed:  4419
# Doc preprocessed:  4420
# Doc preprocessed:  4421
# Doc preprocessed:  4422
# Doc preprocessed:  4423
# Doc preprocessed:  4424
# Doc preprocessed:  4425
# Doc preprocessed:  4426
# Doc preprocessed:  4427
# Doc preprocessed:  4428
# Doc preprocessed:  4429
# Doc preprocessed:  4430
# Doc preprocessed:  4431
# Doc preprocessed:  4432
# Doc preprocessed:  4433
# Doc preprocessed:  4434
# Doc preprocessed:  4435
# Doc preprocessed:  4436
# Doc preprocessed:  4437
# Doc preprocessed:  4438
# Doc preprocessed:  4439
# Doc preprocessed:  4440
# Doc preprocessed:  4441
# Doc preprocessed:  4442
# Doc preprocessed:  4443
# Doc preprocessed:  4444
# Doc preprocessed:  4445
# Doc preprocessed:  4446
# Doc preprocessed:  4447
# Doc preprocessed:  4448
# Doc preprocessed:  4449
# Doc preprocessed:  4450
# Doc preprocessed:  4451
# Doc preprocessed:  4452
# Doc preprocessed:  4453
# Doc preprocessed:  4454
# Doc preprocessed:  4455
# Doc preprocessed:  4456
# Doc preprocessed:  4457
# Doc preprocessed:  4458
# Doc preprocessed:  4459
# Doc preprocessed:  4460
# Doc preprocessed:  4461
# Doc preprocessed:  4462
# Doc preprocessed:  4463
# Doc preprocessed:  4464
# Doc preprocessed:  4465
# Doc preprocessed:  4466
# Doc preprocessed:  4467
# Doc preprocessed:  4468
# Doc preprocessed:  4469
# Doc preprocessed:  4470
# Doc preprocessed:  4471
# Doc preprocessed:  4472
# Doc preprocessed:  4473
# Doc preprocessed:  4474
# Doc preprocessed:  4475
# Doc preprocessed:  4476
# Doc preprocessed:  4477
# Doc preprocessed:  4478
# Doc preprocessed:  4479
# Doc preprocessed:  4480
# Doc preprocessed:  4481
# Doc preprocessed:  4482
# Doc preprocessed:  4483
# Doc preprocessed:  4484
# Doc preprocessed:  4485
# Doc preprocessed:  4486
# Doc preprocessed:  4487
# Doc preprocessed:  4488
# Doc preprocessed:  4489
# Doc preprocessed:  4490
# Doc preprocessed:  4491
# Doc preprocessed:  4492
# Doc preprocessed:  4493
# Doc preprocessed:  4494
# Doc preprocessed:  4495
# Doc preprocessed:  4496
# Doc preprocessed:  4497
# Doc preprocessed:  4498
# Doc preprocessed:  4499
# Doc preprocessed:  4500
# Doc preprocessed:  4501
# Doc preprocessed:  4502
# Doc preprocessed:  4503
# Doc preprocessed:  4504
# Doc preprocessed:  4505
# Doc preprocessed:  4506
# Doc preprocessed:  4507
# Doc preprocessed:  4508
# Doc preprocessed:  4509
# Doc preprocessed:  4510
# Doc preprocessed:  4511
# Doc preprocessed:  4512
# Doc preprocessed:  4513
# Doc preprocessed:  4514
# Doc preprocessed:  4515
# Doc preprocessed:  4516
# Doc preprocessed:  4517
# Doc preprocessed:  4518
# Doc preprocessed:  4519
# Doc preprocessed:  4520
# Doc preprocessed:  4521
# Doc preprocessed:  4522
# Doc preprocessed:  4523
# Doc preprocessed:  4524
# Doc preprocessed:  4525
# Doc preprocessed:  4526
# Doc preprocessed:  4527
# Doc preprocessed:  4528
# Doc preprocessed:  4529
# Doc preprocessed:  4530
# Doc preprocessed:  4531
# Doc preprocessed:  4532
# Doc preprocessed:  4533
# Doc preprocessed:  4534
# Doc preprocessed:  4535
# Doc preprocessed:  4536
# Doc preprocessed:  4537
# Doc preprocessed:  4538
# Doc preprocessed:  4539
# Doc preprocessed:  4540
# Doc preprocessed:  4541
# Doc preprocessed:  4542
# Doc preprocessed:  4543
# Doc preprocessed:  4544
# Doc preprocessed:  4545
# Doc preprocessed:  4546
# Doc preprocessed:  4547
# Doc preprocessed:  4548
# Doc preprocessed:  4549
# Doc preprocessed:  4550
# Doc preprocessed:  4551
# Doc preprocessed:  4552
# Doc preprocessed:  4553
# Doc preprocessed:  4554
# Doc preprocessed:  4555
# Doc preprocessed:  4556
# Doc preprocessed:  4557
# Doc preprocessed:  4558
# Doc preprocessed:  4559
# Doc preprocessed:  4560
# Doc preprocessed:  4561
# Doc preprocessed:  4562
# Doc preprocessed:  4563
# Doc preprocessed:  4564
# Doc preprocessed:  4565
# Doc preprocessed:  4566
# Doc preprocessed:  4567
# Doc preprocessed:  4568
# Doc preprocessed:  4569
# Doc preprocessed:  4570
# Doc preprocessed:  4571
# Doc preprocessed:  4572
# Doc preprocessed:  4573
# Doc preprocessed:  4574
# Doc preprocessed:  4575
# Doc preprocessed:  4576
# Doc preprocessed:  4577
# Doc preprocessed:  4578
# Doc preprocessed:  4579
# Doc preprocessed:  4580
# Doc preprocessed:  4581
# Doc preprocessed:  4582
# Doc preprocessed:  4583
# Doc preprocessed:  4584
# Doc preprocessed:  4585
# Doc preprocessed:  4586
# Doc preprocessed:  4587
# Doc preprocessed:  4588
# Doc preprocessed:  4589
# Doc preprocessed:  4590
# Doc preprocessed:  4591
# Doc preprocessed:  4592
# Doc preprocessed:  4593
# Doc preprocessed:  4594
# Doc preprocessed:  4595
# Doc preprocessed:  4596
# Doc preprocessed:  4597
# Doc preprocessed:  4598
# Doc preprocessed:  4599
# Doc preprocessed:  4600
# Doc preprocessed:  4601
# Doc preprocessed:  4602
# Doc preprocessed:  4603
# Doc preprocessed:  4604
# Doc preprocessed:  4605
# Doc preprocessed:  4606
# Doc preprocessed:  4607
# Doc preprocessed:  4608
# Doc preprocessed:  4609
# Doc preprocessed:  4610
# Doc preprocessed:  4611
# Doc preprocessed:  4612
# Doc preprocessed:  4613
# Doc preprocessed:  4614
# Doc preprocessed:  4615
# Doc preprocessed:  4616
# Doc preprocessed:  4617
# Doc preprocessed:  4618
# Doc preprocessed:  4619
# Doc preprocessed:  4620
# Doc preprocessed:  4621
# Doc preprocessed:  4622
# Doc preprocessed:  4623
# Doc preprocessed:  4624
# Doc preprocessed:  4625
# Doc preprocessed:  4626
# Doc preprocessed:  4627
# Doc preprocessed:  4628
# Doc preprocessed:  4629
# Doc preprocessed:  4630
# Doc preprocessed:  4631
# Doc preprocessed:  4632
# Doc preprocessed:  4633
# Doc preprocessed:  4634
# Doc preprocessed:  4635
# Doc preprocessed:  4636
# Doc preprocessed:  4637
# Doc preprocessed:  4638
# Doc preprocessed:  4639
# Doc preprocessed:  4640
# Doc preprocessed:  4641
# Doc preprocessed:  4642
# Doc preprocessed:  4643
# Doc preprocessed:  4644
# Doc preprocessed:  4645
# Doc preprocessed:  4646
# Doc preprocessed:  4647
# Doc preprocessed:  4648
# Doc preprocessed:  4649
# Doc preprocessed:  4650
# Doc preprocessed:  4651
# Doc preprocessed:  4652
# Doc preprocessed:  4653
# Doc preprocessed:  4654
# Doc preprocessed:  4655
# Doc preprocessed:  4656
# Doc preprocessed:  4657
# Doc preprocessed:  4658
# Doc preprocessed:  4659
# Doc preprocessed:  4660
# Doc preprocessed:  4661
# Doc preprocessed:  4662
# Doc preprocessed:  4663
# Doc preprocessed:  4664
# Doc preprocessed:  4665
# Doc preprocessed:  4666
# Doc preprocessed:  4667
# Doc preprocessed:  4668
# Doc preprocessed:  4669
# Doc preprocessed:  4670
# Doc preprocessed:  4671
# Doc preprocessed:  4672
# Doc preprocessed:  4673
# Doc preprocessed:  4674
# Doc preprocessed:  4675
# Doc preprocessed:  4676
# Doc preprocessed:  4677
# Doc preprocessed:  4678
# Doc preprocessed:  4679
# Doc preprocessed:  4680
# Doc preprocessed:  4681
# Doc preprocessed:  4682
# Doc preprocessed:  4683
# Doc preprocessed:  4684
# Doc preprocessed:  4685
# Doc preprocessed:  4686
# Doc preprocessed:  4687
# Doc preprocessed:  4688
# Doc preprocessed:  4689
# Doc preprocessed:  4690
# Doc preprocessed:  4691
# Doc preprocessed:  4692
# Doc preprocessed:  4693
# Doc preprocessed:  4694
# Doc preprocessed:  4695
# Doc preprocessed:  4696
# Doc preprocessed:  4697
# Doc preprocessed:  4698
# Doc preprocessed:  4699
# Doc preprocessed:  4700
# Doc preprocessed:  4701
# Doc preprocessed:  4702
# Doc preprocessed:  4703
# Doc preprocessed:  4704
# Doc preprocessed:  4705
# Doc preprocessed:  4706
# Doc preprocessed:  4707
# Doc preprocessed:  4708
# Doc preprocessed:  4709
# Doc preprocessed:  4710
# Doc preprocessed:  4711
# Doc preprocessed:  4712
# Doc preprocessed:  4713
# Doc preprocessed:  4714
# Doc preprocessed:  4715
